# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "04865df3",
   "metadata": {},
   "outputs": [],
   "source": [
    "import time\n",
    "import random\n",
    "\n",
    "\n",
    "def interpolation_search(arr, target):\n",
    "    low = 0\n",
    "    high = len(arr) - 1\n",
    "    probes = 0\n",
    "\n",
    "    while low <= high and arr[low] <= target <= arr[high]:\n",
    "\n",
    "        probes += 1\n",
    "\n",
    "        if low == high:\n",
    "            if arr[low] == target:\n",
    "                return low, probes\n",
    "            return -1, probes\n",
    "\n",
    "        if arr[high] == arr[low]:\n",
    "            break\n",
    "\n",
    "        pos = low + int(\n",
    "            ((target - arr[low]) * (high - low))\n",
    "            / (arr[high] - arr[low])\n",
    "        )\n",
    "\n",
    "        if pos < low or pos > high:\n",
    "            break\n",
    "\n",
    "        if arr[pos] == target:\n",
    "            return pos, probes\n",
    "\n",
    "        elif arr[pos] < target:\n",
    "            low = pos + 1\n",
    "\n",
    "        else:\n",
    "            high = pos - 1\n",
    "\n",
    "    return -1, probes\n",
    "\n",
    "\n",
    "# Manual input\n",
    "def manual_input(n):\n",
    "    arr = list(map(int, input(f\"Enter {n} elements separated by spaces: \").split()))\n",
    "\n",
    "    while len(arr) != n:\n",
    "        print(\"Incorrect number of elements!\")\n",
    "        arr = list(map(int, input(f\"Enter exactly {n} elements: \").split()))\n",
    "\n",
    "    arr.sort()\n",
    "    return arr\n",
    "\n",
    "\n",
    "# Uniform dataset generation\n",
    "def generate_uniform(n):\n",
    "    start = random.randint(1, 50)\n",
    "    step = random.randint(2, 10)\n",
    "\n",
    "    arr = []\n",
    "    for i in range(n):\n",
    "        arr.append(start + i * step)\n",
    "\n",
    "    return arr\n",
    "\n",
    "\n",
    "# Non-uniform dataset generation\n",
    "def generate_non_uniform(n):\n",
    "    arr = []\n",
    "    current = random.randint(1, 10)\n",
    "\n",
    "    for i in range(n):\n",
    "        current += random.randint(1, 100)\n",
    "        arr.append(current)\n",
    "\n",
    "    return arr\n",
    "\n",
    "\n",
    "def perform_search(arr, key):\n",
    "\n",
    "    start_time = time.perf_counter()\n",
    "\n",
    "    index, probes = interpolation_search(arr, key)\n",
    "\n",
    "    end_time = time.perf_counter()\n",
    "\n",
    "    execution_time = end_time - start_time\n",
    "\n",
    "    if index != -1:\n",
    "        print(\"\\nKey found!\")\n",
    "        print(\"Index position:\", index)\n",
    "    else:\n",
    "        print(\"\\nKey not found!\")\n",
    "\n",
    "    print(\"Number of probes/comparisons:\", probes)\n",
    "    print(\"Execution time:\", execution_time, \"seconds\")\n",
    "\n",
    "    return probes, execution_time\n",
    "\n",
    "\n",
    "# ---------------- MAIN PROGRAM ----------------\n",
    "\n",
    "print(\"========== INTERPOLATION SEARCH ==========\\n\")\n",
    "\n",
    "# Dataset type\n",
    "print(\"1. Uniform Dataset\")\n",
    "print(\"2. Non-Uniform Dataset\")\n",
    "\n",
    "dataset_choice = int(input(\"Enter choice: \"))\n",
    "\n",
    "# Input type\n",
    "print(\"\\n1. Manual Input\")\n",
    "print(\"2. Random Generation\")\n",
    "\n",
    "input_choice = int(input(\"Enter choice: \"))\n",
    "\n",
    "n = int(input(\"\\nEnter number of elements: \"))\n",
    "\n",
    "# Build dataset\n",
    "if input_choice == 1:\n",
    "\n",
    "    arr = manual_input(n)\n",
    "\n",
    "else:\n",
    "\n",
    "    if dataset_choice == 1:\n",
    "        arr = generate_uniform(n)\n",
    "    else:\n",
    "        arr = generate_non_uniform(n)\n",
    "\n",
    "print(\"\\nSorted Dataset:\")\n",
    "print(arr)\n",
    "\n",
    "key = int(input(\"\\nEnter search key: \"))\n",
    "\n",
    "probes, execution_time = perform_search(arr, key)\n",
    "\n",
    "# Comparison section\n",
    "print(\"\\n========== PERFORMANCE COMPARISON ==========\")\n",
    "\n",
    "uniform_arr = generate_uniform(n)\n",
    "non_uniform_arr = generate_non_uniform(n)\n",
    "\n",
    "_, uniform_probes = interpolation_search(uniform_arr, key)\n",
    "_, non_uniform_probes = interpolation_search(non_uniform_arr, key)\n",
    "\n",
    "print(\"Uniform Dataset Probes     :\", uniform_probes)\n",
    "print(\"Non-Uniform Dataset Probes :\", non_uniform_probes)\n",
    "\n",
    "if uniform_probes < non_uniform_probes:\n",
    "    print(\"\\nConclusion:\")\n",
    "    print(\"Interpolation Search performs better on uniformly distributed data.\")\n",
    "elif uniform_probes > non_uniform_probes:\n",
    "    print(\"\\nConclusion:\")\n",
    "    print(\"Interpolation Search performs better on non-uniform data.\")\n",
    "else:\n",
    "    print(\"\\nConclusion:\")\n",
    "    print(\"Both datasets showed similar performance.\")"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
